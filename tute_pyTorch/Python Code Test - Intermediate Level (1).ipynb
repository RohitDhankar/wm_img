# %% [markdown]
# #### 1.) Sum of Integers
# **Scenario:**
#
# Write a function, sum_it_up(), that takes a single integer as input and returns the sum of the integers from zero to the input parameter.
#
# The function should return 0 if a non-integer is passed in.
#
# ##### HINT: Debug the below code, Expected result = 1540

# %%
def sum_it_up(n):
    num = 57
    sum = 0
    print("-num---aa-",num)
      print("-sum--bb-",sum)
        sum = sum + num

        #num = num + 1
        print("-num--bb-",num)
    if sum == 1540:
      return sum
    else:
      print("---NotYet")

sum_it_up(55)
# Out:
#   File "<ipython-input-1-fa938d5ce3a7>", line 5
#     print("-sum--bb-",sum)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# #### 2.) Text Substitute
# **Scenario:**
#
# You are to write a function that accepts two arguments, a plain-text message and a number of letters to shift in the text. The function will return an encrypted string with all letters transformed and all punctuation and whitespace remaining unchanged.
#
# For example, assume the input plain text is the following:
# abcd xyz
#
# If the shift value, n, is 4, then the encrypted text would be the following:
# efgh bcd
#
# ##### HINT: use approproate function in the below code

# %%
import string

def caesar(plain_text, shift_num=1):
   
    print("-shift_num--",shift_num)
    letters = string.ascii_lowercase
    print("letters--",letters)
    mask = letters[shift_num:] + letters[:shift_num]
    print("mask--",mask)
    
    trantab = str.maketrans(letters, mask)
    print("trantab--",trantab)
    
    return plain_text.translate(trantab)

#caesar('this is string', 4)
caesar('abc', 2)
# Out:
# -shift_num-- 2
# letters-- abcdefghijklmnopqrstuvwxyz
# mask-- cdefghijklmnopqrstuvwxyzab
# trantab-- {97: 99, 98: 100, 99: 101, 100: 102, 101: 103, 102: 104, 103: 105, 104: 106, 105: 107, 106: 108, 107: 109, 108: 110, 109: 111, 110: 112, 111: 113, 112: 114, 113: 115, 114: 116, 115: 117, 116: 118, 117: 119, 118: 120, 119: 121, 120: 122, 121: 97, 122: 98}
# 'cde'

# %% [markdown]
# #### 3.) Fix the below code
#
# ##### HINT: Expected output
# 1
# 2
# 3

# %%
class ArrayList:
    def __init__(self, number_list):
        self.numbers = number_list

    def __iter__(self):
        self.pos = 0
        return self

    def __next__(self):
        if(self.pos < len(self.numbers)):
            self.pos += 1
            return self.numbers[self.pos - 1]
        else:
            raise StopIteration

array_obj = ArrayList([1, 2, 3])

it = iter(array_obj)

print(next(it)) #output: 1
print(next(it)) #output: 2
print(next(it)) #output: 3
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### 4.) Concatenate Strings
# **Scenario:**
#
# Write a function which takes a list of strings as an argument and returns, as a single-value result, the concatenation of all of these strings.
#
# ##### HINT: Fix error in the below code, Expected output: 'string-1_string-2_'

# %%
def concat_function(args):
    temp_string = ''
    for word in args:
        temp_string += word
    return temp_string

concat_function(['string-1', 'string-2'])
# Out:
# 'string-1string-2'

# %% [markdown]
# #### 5.) Fix the below code
#
# ##### HINT: Expected output: True

# %%
class fruit:
      def __init__(self,type,size):
              type='fruit'
              type=type
              size=size
      def __gt__(self,other):
              if self.size>other.size:
                       return True
              return False
        
        
orange=fruit('orange',7)
apple=fruit('apple',8)
apple>orange

# %% [markdown]
# #### 6.) Sum of cubes
# **Scenario:**
#
# Write a Python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number.
#
# ![image.png](attachment:image.png)
#
# ##### HINT: Debug the below code, Expected output: Sum of cubes:  9

# %%
def sum_of_cubes(n):
  #total = 0
  num1 = n -1 
  num2 = n -2
  
  cube_num1 = num1 * num1 * num1
  cube_num2 = num2 * num2 * num2
  total_cubes = cube_num2 + cube_num1
  print("total_cubes",total_cubes)
  
  
  
#   while n > 0:
#     total += n * n * n
#     print("tota--",total)
#     n -= 1
#   return total
print("Sum of cubes: ",sum_of_cubes(4)) ## Expected output = 9
# Out:
# total_cubes 35
# Sum of cubes:  None

# %% [markdown]
# #### 7.) Football & Cricket
# **Scenario:**
#
# There is a sports tournament happening, 2 competitition cricket and football. There are 2 lists of students who are participating. Some students are participating in both cricket and football. Teachers would like to know whats the total count of students who are participating in both football and cricket
#
# ids are student ids
# football = [1,2,3,4,5]
#
# cricket  = [2,5,10,15]
#
# expected output = 7
#
# ##### HINT: Use appropriate method in the below code, Expected output: 7

# %%
football = [1,2,3,4,5]
cricket  = [2,5,10,15]
total=list()
total.update(football,cricket)
print(len(total))

# %% [markdown]
# #### 8.) Compound Interest
# **Scenario:**
#
# Formula to calculate compound interest annually is given by:
#
# A = P(1 + R/100) t
#
# Compound Interest = A – P
#
# Where,
# A is amount
#
# P is principle amount
#
# R is the rate and
#
# T is the time span
#
#
# ##### HINT: use appropriate method in the below code, Expected output: Compound interest is 6288.946267774416

# %%
def compound_interest(principle, rate, time): 
    Amount = principle * (power((1 + rate / 100), time)) 
    CI = Amount - principle 
    print("Compound interest is", CI) 
  

compound_interest(10000, 10.25, 5)

# %% [markdown]
# #### 9.) Print the number pattern as follows
#
# ##### HINT: Print the pattern
# |****
#
# |*
#
# |***
#
# |**
#
# |*****

# %%
def digipattern(n): 
    for i in n: 
        print("|", end = "") 
        print("*" * int(i)) 
        
    n = "41325"
    digipattern(n)

# %% [markdown]
# #### 10.) Check below string is palindrome or not
# ##### HINTL: Debug the below code, Expected output: True

# %%
def isPalindromeText(string):
     left,right=0,len(string)-1
     while right>=left:
             if string[left]==string[right]:
                      return False
             left+=1
             right-=1
             return True

isPalindromeText('MALAYALAM')
